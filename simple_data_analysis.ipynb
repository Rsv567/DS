# %% [markdown]
# # <a href="https://thetahat.ru/courses/ad">Введение в анализ данных</a>
# ## Домашнее задание 2. Простой анализ данных и ИИ-инструменты.

# %% [markdown]
# **Правила, <font color="red">прочитайте внимательно</font>:**
#
# * Выполненную работу нужно отправить телеграм-боту `@thetahat_ds25_bot`. Для начала работы с ботом каждый раз отправляйте `/start`. Дождитесь подтверждения от бота, что он принял файл. Если подтверждения нет, то что-то не так. **Работы, присланные иным способом, не принимаются.**
# * Дедлайн см. в боте. После дедлайна работы не принимаются кроме случаев наличия уважительной причины.
# * Прислать нужно **ноутбук в формате `ipynb`**. Если вы строите интерактивные графики, их стоит прислать в формате html.
# * Следите за размером файлов. **Бот не может принимать файлы весом более 20 Мб.** Если файл получается больше, заранее разделите его на несколько.
# * Выполнять задание необходимо полностью самостоятельно. **При обнаружении списывания всем участникам списывания дается штраф -2 балла к итоговой оценке за семестр.**
# * Решения, размещенные на каких-либо интернет-ресурсах, не принимаются. Кроме того, публикация решения в открытом доступе может быть приравнена к предоставлении возможности списать.
# * Обратите внимание на <a href="https://thetahat.ru/courses/ai-rules"><b>правила использования ИИ-инструментов</b></a> при решении домашнего задания.
# * **Код из рассказанных на занятиях ноутбуков** можно использовать без ограничений.
# * Для выполнения задания используйте этот ноутбук в качестве основы, ничего не удаляя из него. Можно добавлять необходимое количество ячеек.
# * Комментарии к решению пишите в markdown-ячейках.
# * Выполнение задания (ход решения, выводы и пр.) должно быть осуществлено на русском языке.
# * Решение проверяется системой ИИ-проверки <a href="https://thetahat.ru/"><img src="https://miptstats.github.io/theta_grader_small.png" style="display: inline; vertical-align: middle;"></a> **ThetaGrader**. Результат проверки валидируется и исправляется человеком, после чего комментарии отправляются студентам.
# * Если код будет не понятен проверяющему, оценка может быть снижена.
# * Никакой код из данного задания при проверке запускаться не будет. *Если код студента не выполнен, недописан и т.д., то он не оценивается.*
#
# <b><font size="5" color="red">Важно!!! Правила заполнения ноутбука:</font></b>
# * Запрещается удалять имеющиеся в ноутбуке ячейки, менять местами положения задач.
# * Сохраняйте естественный линейный порядок повествования в ноутбуке сверху-вниз.
# * Отвечайте на вопросы, а также добавляйте новые ячейки в предложенных местах, которые обозначены `<...>`.
# * В markdown-ячейка, содержащих описание задачи, находятся специальные отметки, которые <font color="red"><b>запрещается модифицировать</b></font>.
# * При нарушении данных правил работа может получить 0 баллов.
#
#
# **Перед выполнением задания посмотрите презентацию по выполнению и оформлению домашних заданий с занятия 2.**
#
#
# **Баллы за задание:**
#
# <b><font color="blue">Легкая часть</font></b> (достаточно на "хор"):
# * Задача 1 &mdash; 5 баллов
# * Задача 2 &mdash; 25 баллов
#
# <b><font color="orange">Сложная часть</font></b> (необходимо на "отл"):
# * Задача 3 &mdash; 80 баллов
# * Задача 4 &mdash; 50 баллов
#
# Баллы учитываются в <b>обязательной части</b> курса и не влияют на оценку по факультативной части.

# %%
# Bot check

# HW_ID: fpmi_ad2
# Бот проверит этот ID и предупредит, если случайно сдать что-то не то

# Status: final
# Перед отправкой в финальном решении удали "not" в строчке выше
# Так бот проверит, что ты отправляешь финальную версию, а не промежуточную

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


sns.set(style='whitegrid', palette='Set2')

# %% [markdown]
# На лекции мы рассмотрели, как можно использовать инструменты искусственного интеллекта в нашем курсе, чтобы повысить личную эффективность. В этом домашнем задании мы предлагаем вам две технические задачи, которые можно полностью доверить ИИ. Они относятся к <b><font color="blue">легкой части</font></b> задания. Бывает работа, которую делать просто не хочется: она долгая, рутинная, несодержательная, не несет какой-либо интеллектуальной ценности. Такую работу по возможности стоит спихнуть искусственному интеллекту.
#
#
# Также в <b><font color="orange">сложной части</font></b> вы найдёте задачу по работе с библиотеками и небольшой анализ научной статьи из списка на ваш выбор. Все эти задания можно выполнить самостоятельно, но мы рекомендуем воспользоваться помощью ИИ, чтобы облегчить процесс 😊

# %% [markdown]
# ---
# ### <font color="orange"><i>Легкая часть</i></font>

# %% [markdown]
# ### Задача 1.

# %% [markdown]
# <!-- Внимание! Здесь находится специальная отметка. Ее нельзя удалять! Ответы на вопросы / выводы для предыдущего пункта(ов) пиши в ячейках выше! -->
# <!-- 401c68baed5870bfd4cb4374e9a69caf -->
# Это задача для разминки всего на 5 баллов. Возможно, она покажется вам забавной, но это действительно так 😃
#
# Ниже представлен код на языке C++. Перепишите его на Python и запустите без ошибок. Поясните, что делает этот код?
#
# Если код не работает, обсудите проблему с моделью или используйте другую, эта задача гарантированно решается.

# %%
#include <iostream>
#include <vector>
#include <cstdlib>
#include <ctime>

#define 😃 int
#define 🎉 void
#define 🍎 std::vector<int>
#define 🖨️ std::cout
#define 🔢 rand()
#define ⏰ time(0)
#define 🔀 srand
#define 🔁 for
#define 🔄 while
#define 🎲 if
#define 🎈 else
#define 🚀 return
#define 🎯 main
#define 🖥️ std::endl

🎉 🎭(🍎& 🍏, 😃 🍌, 😃 🍍, 😃 🍇) {
    😃 🍒 = 🍍 - 🍌 + 1;
    😃 🍓 = 🍇 - 🍍;

    🍎 🍑(🍒), 🍐(🍓);

    🔁 (😃 🍔 = 0; 🍔 < 🍒; 🍔++)
        🍑[🍔] = 🍏[🍌 + 🍔];
    🔁 (😃 🍔 = 0; 🍔 < 🍓; 🍔++)
        🍐[🍔] = 🍏[🍍 + 1 + 🍔];

    😃 🍔 = 0, 🍕 = 0, 🍖 = 🍌;
    🔄 (🍔 < 🍒 && 🍕 < 🍓) {
        🎲 (🍑[🍔] <= 🍐[🍕]) {
            🍏[🍖] = 🍑[🍔];
            🍔++;
        } 🎈 {
            🍏[🍖] = 🍐[🍕];
            🍕++;
        }
        🍖++;
    }

    🔄 (🍔 < 🍒) {
        🍏[🍖] = 🍑[🍔];
        🍔++;
        🍖++;
    }

    🔄 (🍕 < 🍓) {
        🍏[🍖] = 🍐[🍕];
        🍕++;
        🍖++;
    }
}

🎉 🍿(🍎& 🍏, 😃 🍌, 😃 🍇) {
    🎲 (🍌 < 🍇) {
        😃 🍍 = 🍌 + (🍇 - 🍌) / 2;

        🍿(🍏, 🍌, 🍍);
        🍿(🍏, 🍍 + 1, 🍇);

        🎭(🍏, 🍌, 🍍, 🍇);
    }
}

🍎 🎲(😃 🎯, 😃 🎰, 😃 🎳) {
    🍎 🎨(🎯);
    🔁 (😃 🍔 = 0; 🍔 < 🎯; 🍔++) {
        🎨[🍔] = 🔢 % (🎳 - 🎰 + 1) + 🎰;
    }
    🚀 🎨;
}

🎉 🖨️(const 🍎& 🍏) {
    🔁 (😃 🍔 : 🍏) {
        🖨️ << 🍔 << " ";
    }
    🖨️ << 🖥️;
}

😃 🎯() {
    🔀(⏰);

    😃 🎯 = 20;
    😃 🎰 = 0;
    😃 🎳 = 100;

    🍎 🍏 = 🎲(🎯, 🎰, 🎳);

    🖨️ << "?: ";
    🖨️(🍏);

    🍿(🍏, 0, 🍏.size() - 1);

    🖨️ << "??: ";
    🖨️(🍏);

    🚀 0;
}

# %%
import random

def merge(arr, left, mid, right):
    left_part = arr[left:mid+1]
    right_part = arr[mid+1:right+1]

    i = j = 0
    k = left

    while i < len(left_part) and j < len(right_part):
        if left_part[i] <= right_part[j]:
            arr[k] = left_part[i]
            i += 1
        else:
            arr[k] = right_part[j]
            j += 1
        k += 1

    while i < len(left_part):
        arr[k] = left_part[i]
        i += 1
        k += 1

    while j < len(right_part):
        arr[k] = right_part[j]
        j += 1
        k += 1

def merge_sort(arr, left, right):
    if left < right:
        mid = left + (right - left) // 2
        merge_sort(arr, left, mid)
        merge_sort(arr, mid + 1, right)
        merge(arr, left, mid, right)

def generate_random_list(size, min_val, max_val):
    return [random.randint(min_val, max_val) for _ in range(size)]

def print_list(arr):
    print(" ".join(map(str, arr)))

def main():
    random.seed()
    size = 20
    min_val = 0
    max_val = 100

    arr = generate_random_list(size, min_val, max_val)
    print("?:", end=" ")
    print_list(arr)

    merge_sort(arr, 0, len(arr) - 1)

    print("??:", end=" ")
    print_list(arr)

if __name__ == "__main__":
    main()
# Out:
# ?: 94 100 67 56 60 62 38 61 55 72 87 10 75 87 65 96 83 0 41 94
# ??: 0 10 38 41 55 56 60 61 62 65 67 72 75 83 87 87 94 94 96 100

# %% [markdown]
# **Пояснение к коду:**
# - Функция merge выполняет слияние двух отсортированных частей списка.
# - Функция merge_sort реализует алгоритм сортировки слиянием.
# -  Функция generate_random_list генерирует случайный список заданного размера и диапазона значений.
# -    Функция print_list выводит список в удобочитаемом формате.
# -    Функция main управляет процессом: генерирует случайный список, сортирует его и выводит до и после сортировки.
#
# Этот код сортирует массив случайных чисел методом слияния и показывает результат до и после сортировки.

# %% [markdown]
# <!-- Внимание! Здесь находится специальная отметка. Ее нельзя удалять! Ответы на вопросы / выводы для предыдущего пункта(ов) пиши в ячейках выше! -->
# <!-- f29fb05ffea036749d60c61d0373738b -->
# ---
# ### Задача 2.
#
# **При использовании ИИ в этой задаче необходимо прислать файл `task_2_ai_promt.txt` с копией вашего диалога с ИИ-инструментом**
#
# В этой задаче вам предстоит поработать с библиотекой Plotly. Это полезный инструмент для создания привлекательных и удобных графиков, который вы наверняка будете использовать в своей работе. Мы рекомендуем заранее изучить его функции и возможности, чтобы вы могли уверенно использовать его в дальнейшем.
#
# Одна из главных особенностей этой библиотеки — возможность настраивать и украшать графики по своему вкусу. Именно этим мы и предлагаем вам заняться в рамках данной задачи.
#
# Ниже приведен код для построения 3D-графика функции с помощью Plotly.

# %%
import plotly.graph_objects as go


def plot_3d_surface():
    x = np.linspace(-10, 10, 200)
    y = np.linspace(-10, 10, 200)
    x, y = np.meshgrid(x, y)
    z = np.cos(np.sqrt(x**2 + y**2))

    fig = go.Figure(data=[go.Surface(z=z, x=x, y=y)])
    fig.update_layout(
        title='Cosine Function 3D Surface Plot',
        scene=dict(
            xaxis_title='X Axis',
            yaxis_title='Y Axis',
            zaxis_title='Z Axis',
            aspectmode='cube',
        ),
        margin=dict(l=0, r=0, b=0, t=0)
    )


    fig.show()

plot_3d_surface()

# %% [markdown]
# Выполните следующие действия в ячейках ниже.
#
# 1. Задокументируйте функцию и добавьте комментариев. Необходимо это сделать так, чтобы любой человек мог понять, какая у нее задача и что делают отдельные части кода.

# %%
# Импортируем модуль для работы с графическими объектами Plotly
import plotly.graph_objects as go
import numpy as np  # Добавим импорт numpy, так как np используется в коде

# Определяем функцию для построения 3D-графика поверхности
def plot_3d_surface():
    # Создаем массивы значений X и Y в диапазоне от -10 до 10 с 200 шагами
    x = np.linspace(-10, 10, 200)
    y = np.linspace(-10, 10, 200)

    # Создаем координатную сетку
    x, y = np.meshgrid(x, y)

    # Вычисляем значения Z на основе косинусной функции
    z = np.cos(np.sqrt(x**2 + y**2))

    # Создаем объект графика с поверхностью
    fig = go.Figure(data=[go.Surface(z=z, x=x, y=y)])

    # Настраиваем параметры отображения графика
    fig.update_layout(
        title='Cosine Function 3D Surface Plot',  # Заголовок графика
        scene=dict(
            xaxis_title='X Axis',  # Подпись оси X
            yaxis_title='Y Axis',  # Подпись оси Y
            zaxis_title='Z Axis',  # Подпись оси Z
            aspectmode='cube',  # Устанавливаем соотношение сторон в виде куба
        ),
        margin=dict(l=0, r=0, b=0, t=0)  # Убираем внешние отступы
    )

    # Отображаем график
    fig.show()

# Вызываем функцию для построения графика
plot_3d_surface()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# <!-- Внимание! Здесь находится специальная отметка. Ее нельзя удалять! Ответы на вопросы / выводы для предыдущего пункта(ов) пиши в ячейках выше! -->
# <!-- 5cb0979db038779eea74747578c4bf85 -->
# 2. Напишите, что делают следующие функции и опции:
#
#
# *  `meshgrid`
#
# *  `Figure`
#
# *  `Surface`
#
# *  `update_layout`
#
# *  `scene`
#
# *  `margin`

# %% [markdown]
#     meshgrid (из numpy):
#     Создает координатные сетки из одномерных массивов x и y. Возвращает две 2D-матрицы, где каждая строка первой матрицы содержит копии значений x, а каждый столбец второй матрицы — копии y. Это полезно для построения поверхностей в 3D-графиках.
#
#     Figure (из plotly.graph_objects):
#     Создает объект графика, который может содержать один или несколько элементов визуализации (например, поверхности, линии, точки и т. д.).
#
#     Surface (из plotly.graph_objects):
#     Отвечает за создание 3D-поверхности на графике. В данном случае используется для визуализации функции z = cos(sqrt(x^2 + y^2)) как цветной поверхности.
#
#     update_layout:
#     Позволяет изменять настройки отображения графика, такие как заголовок, подписи осей, цвет фона и другие параметры.
#
#     scene:
#     Определяет параметры трехмерного пространства (3D-сцены), включая подписи осей (xaxis_title, yaxis_title, zaxis_title) и соотношение сторон (aspectmode).
#
#     margin:
#     Определяет отступы (в пикселях) вокруг графика. Например, margin=dict(l=0, r=0, b=0, t=0) убирает отступы слева, справа, снизу и сверху, чтобы график заполнял доступное пространство.

# %% [markdown]
# <!-- Внимание! Здесь находится специальная отметка. Ее нельзя удалять! Ответы на вопросы / выводы для предыдущего пункта(ов) пиши в ячейках выше! -->
# <!-- 2b7cf6390aa01f97d4e01e8c39bb1c82 -->
# 3. Выясните, какой параметр отвечает за настройку цветовой палитры графика? Измените код так, чтобы палитра была от светло-розового до светло-голубого.

# %% [markdown]
# В Plotly параметр, отвечающий за настройку цветовой палитры 3D-поверхности, — это colorscale.

# %%
import plotly.graph_objects as go
import numpy as np

def plot_3d_surface():
    x = np.linspace(-10, 10, 200)
    y = np.linspace(-10, 10, 200)
    x, y = np.meshgrid(x, y)
    z = np.cos(np.sqrt(x**2 + y**2))

    # Создаем кастомную цветовую шкалу от светло-розового до светло-голубого
    custom_colorscale = [
        [0, 'rgb(255, 182, 193)'],  # Светло-розовый
        [1, 'rgb(173, 216, 230)']   # Светло-голубой
    ]

    fig = go.Figure(data=[go.Surface(z=z, x=x, y=y, colorscale=custom_colorscale)])

    fig.update_layout(
        title='Cosine Function 3D Surface Plot',
        scene=dict(
            xaxis_title='X Axis',
            yaxis_title='Y Axis',
            zaxis_title='Z Axis',
            aspectmode='cube',
        ),
        margin=dict(l=0, r=0, b=0, t=0)
    )

    fig.show()

plot_3d_surface()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# <!-- Внимание! Здесь находится специальная отметка. Ее нельзя удалять! Ответы на вопросы / выводы для предыдущего пункта(ов) пиши в ячейках выше! -->
# <!-- fef35e7717db0ff880eb1f1ebf35cee3 -->
# 4. Измените функцию так, чтобы она могла получать любые параметры настройки графиков через `kwargs`. Это позволит пользователям гибко настраивать параметры графика.
#
# ...И напишите подробную инструкцию для пользователя этой функции😃

# %%
import plotly.graph_objects as go
import numpy as np

def plot_3d_surface(**kwargs):
    x = np.linspace(-10, 10, 200)
    y = np.linspace(-10, 10, 200)
    x, y = np.meshgrid(x, y)
    z = np.cos(np.sqrt(x**2 + y**2))

    # Создаем кастомную цветовую шкалу от светло-розового до светло-голубого
    custom_colorscale = kwargs.get('colorscale', [
        [0, 'rgb(255, 182, 193)'],  # Светло-розовый
        [1, 'rgb(173, 216, 230)']   # Светло-голубой
    ])

    fig = go.Figure(data=[go.Surface(z=z, x=x, y=y, colorscale=custom_colorscale)])

    layout_defaults = {
        'title': 'Cosine Function 3D Surface Plot',
        'scene': dict(
            xaxis_title='X Axis',
            yaxis_title='Y Axis',
            zaxis_title='Z Axis',
            aspectmode='cube',
        ),
        'margin': dict(l=0, r=0, b=0, t=0)
    }

    layout_defaults.update(kwargs)
    fig.update_layout(**layout_defaults)

    fig.show()

plot_3d_surface()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# **Инструкция:**
# Функция plot_3d_surface позволяет строить 3D-графики для функции z=cos⁡(x2+y2)z=cos(x2+y2
#
# ​), с возможностью настройки различных параметров графика.
# 1. Вызов функции с настройками по умолчанию
#
# plot_3d_surface()
#
# Отобразит 3D-график функции z=cos⁡(x2+y2)z=cos(x2+y2
#
# ​) в диапазоне x,y∈[−10,10]x,y∈[−10,10] с цветовой шкалой от светло-розового до светло-голубого.
# 2. Изменение заголовка графика
#
# plot_3d_surface(title="Мой 3D-график")
#
# Позволяет задать пользовательский заголовок графика.
# 3. Изменение цветовой шкалы
#
# plot_3d_surface(colorscale=[[0, 'rgb(0, 255, 0)'],  # Зеленый
#                              [1, 'rgb(0, 0, 255)']])  # Синий
#
# Позволяет задать пользовательскую цветовую шкалу для графика.
# 4. Изменение подписей осей
#
# plot_3d_surface(scene=dict(
#     xaxis_title='Новая ось X',
#     yaxis_title='Новая ось Y',
#     zaxis_title='Новая ось Z'
# ))
#
# Позволяет задать собственные названия для осей XX, YY, и ZZ.
# 5. Изменение масштаба осей
#
# plot_3d_surface(scene=dict(
#     aspectmode='manual',
#     aspectratio=dict(x=2, y=1, z=0.5)
# ))
#
# Позволяет задать нестандартные пропорции осей. Например, ось XX будет в два раза длиннее оси YY, а ось ZZ будет в два раза короче оси XX.
#
# Примечание: Все параметры передаются через kwargs и обновляют стандартные настройки графика, что позволяет легко кастомизировать внешний вид 3D-графика.

# %% [markdown]
# <!-- Внимание! Здесь находится специальная отметка. Ее нельзя удалять! Ответы на вопросы / выводы для предыдущего пункта(ов) пиши в ячейках выше! -->
# <!-- 00000000000000000000000000000000 -->
# ---
# ### <font color="orange"><i>Сложная часть</i></font>

# %% [markdown]
# ### Задача 3.
#
# Эта задача предназначена для развития навыков работы с библиотекой pandas и простого анализа табличных данных. В ней детально описаны все шаги, которые необходимо выполнить. Если что-то не понятно, спросите ИИ или в чате курса.

# %% [markdown]
# <a target="_blank" href="https://www.yelp.com/">Yelp</a> — веб-сайт для поиска на местном рынке услуг, например ресторанов или парикмахерских, с возможностью добавлять и просматривать рейтинги и обзоры этих услуг. Для популярных бизнесов имеются сотни обзоров. Для обозревателей на сайте предусмотрены элементы социальной сети.
#
# ![Yelp](https://upload.wikimedia.org/wikipedia/commons/thumb/a/ad/Yelp_Logo.svg/300px-Yelp_Logo.svg.png)
#
# _____________
#
# Вам предоставляется следующая информация о компаниях на Yelp:
#
# Файл `yelp_business.csv`:
# * `business_id` — уникальный идентификатор компании;
# * `name` — имя компании;
# * `address`, `city`, `state` — месторасположении компании;
# * `latitude`, `longitude` — географические координаты;
# * `categories` — категории услуг компании.
#
# Файл `yelp_review.csv`, содержащий оценки пользователей:
# * `business_id` — идентификатор компании, соответствующий файлу `yelp_business.csv`;
# * `stars` — поставленная пользователем оценка от 1 до 5.
#
# В целях сокращения объема файла, текстовые отзывы пользователей не были включены.
#
# Оригинальную версию датасета в формате `json` можно посмотреть по <a target="_blank" href="https://www.kaggle.com/yelp-dataset/yelp-dataset/data">ссылке</a>, но использовать нужно выданные данные.
#
# _____________
#
# **Что нужно сделать:**
#
# * Найти город с наибольшим количеством компаний;
# * Для этого города определить районы с наиболее качественными услугами. <a target="_blank" href="https://yandex.ru/company/researches/2017/msk_mobile_map">Пример</a> с несколько другой задачей.
# * А также найти рестораны с наилучшими отзывами.
#
#
# *Далее в условии встречаются различные подсказки, как можно выполнить определенные части задачи. Вы можете их игнорировать и делать иным способом для получения **того же самого промежуточного результата**. Однако, если ваше решение окажется **значительно** менее эффективным (по скорости, количеству и красоте кода) по сравнению с предполагаемым, баллы могут быть снижены.*
#
# ------

# %% [markdown]
# #### 1. Город с наибольшим количеством компаний
#
# Загрузите данные из файла `yelp_business.csv` с помощью функции `pd.read_csv`. Посмотрите на первые несколько строк с помощью метода `head`.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px
import folium

# %%
df = pd.read_csv("yelp_business.csv")

print(df.head())
# Out:
#    Unnamed: 0             business_id                        name  \
# 0           0  FYWN1wneV18bWNgQjJ2GNg          "Dental by Design"
# 1           1  He-G7vWjzVUysIKrfNbPUQ       "Stephen Szabo Salon"
# 2           2  KQPW8lFf1y5BT2MxiSZ3QA     "Western Motor Vehicle"
# 3           3  8DShNS-LuFqpEWIp0HxijA          "Sports Authority"
# 4           4  PfOCPjBrlQAnz__NXj9h_w  "Brick House Tavern + Tap"
#
#   neighborhood                           address            city state  \
# 0          NaN        "4855 E Warner Rd, Ste B9"       Ahwatukee    AZ
# 1          NaN              "3101 Washington Rd"        McMurray    PA
# 2          NaN          "6025 N 27th Ave, Ste 1"         Phoenix    AZ
# 3          NaN  "5000 Arizona Mills Cr, Ste 435"           Tempe    AZ
# 4          NaN                    "581 Howe Ave"  Cuyahoga Falls    OH
#
#   postal_code   latitude   longitude  is_open  \
# 0       85044  33.330690 -111.978599        1
# ...

# %% [markdown]
# Найдите пять городов, по которым присутствует информация о наибольшем количестве компаний. В таблице должен быть указан город (название) и количество компаний в этом городе.
#
# *Подсказка.* Для выполнения стоит воспользоваться методами `groupby`, `count`, `sort_values`, `head`.

# %%
city_counts = df.groupby('city').size().reset_index(name='company_count')

top_cities = city_counts.sort_values(by='company_count', ascending=False).head(5)

print(top_cities)
# Out:
#            city  company_count
# 424   Las Vegas          26775
# 713     Phoenix          17213
# 983     Toronto          17206
# 143   Charlotte           8553
# 871  Scottsdale           8228

# %% [markdown]
# <!-- Внимание! Здесь находится специальная отметка. Ее нельзя удалять! Ответы на вопросы / выводы для предыдущего пункта(ов) пиши в ячейках выше! -->
# <!-- e7cca0cc751f37cd60e6ee92b5464ba1 -->
# Пусть `N` &mdash; город с наибольшим количеством компаний. Оставьте в таблице только записи, соответствующие городу `N`. Нанесите все эти компании на график, в котором по оси $x$ отметьте долготу, а по оси $y$ &mdash; широту.

# %%
city_max_companies = city_counts.loc[city_counts['company_count'].idxmax(), 'city']

df_city_max = df[df['city'] == city_max_companies]

plt.figure(figsize=(10, 6))
plt.scatter(df_city_max['longitude'], df_city_max['latitude'], alpha=0.5, c='blue', edgecolors='k', s=10)
plt.title(f"Компании в городе {city_max_companies}")
plt.xlabel("Долгота")
plt.ylabel("Широта")
plt.grid(True)
plt.show()

# %% [markdown]
# Сам город находится в сгустке точек. Есть какие-то компании, которые приписаны к этому городу, но находятся далеко от него. Избавьтесь от них, подобрав некоторые границы значений широты и долготы. Изобразите все компании на новом графике. На этом графике должны выделяться некоторые улицы.

# %%
latitude_mean = df_city_max['latitude'].mean()
longitude_mean = df_city_max['longitude'].mean()

latitude_range = (latitude_mean - 0.1, latitude_mean + 0.1)
longitude_range = (longitude_mean - 0.1, longitude_mean + 0.1)

df_filtered = df_city_max[
    (df_city_max['latitude'] >= latitude_range[0]) & (df_city_max['latitude'] <= latitude_range[1]) &
    (df_city_max['longitude'] >= longitude_range[0]) & (df_city_max['longitude'] <= longitude_range[1])
]

plt.figure(figsize=(10, 6))

plt.scatter(df_filtered['longitude'], df_filtered['latitude'], alpha=0.5, c='blue', edgecolors='k', s=10)

street_latitudes = [latitude_mean + 0.02, latitude_mean - 0.03]
street_longitudes = [longitude_mean + 0.02, longitude_mean - 0.04]

plt.title(f"Компании в городе {city_max_companies} (с отфильтрованными данными)")
plt.xlabel("Долгота")
plt.ylabel("Широта")
plt.grid(True)

plt.show()

# %% [markdown]
# <!-- Внимание! Здесь находится специальная отметка. Ее нельзя удалять! Ответы на вопросы / выводы для предыдущего пункта(ов) пиши в ячейках выше! -->
# <!-- 3886558247e1540e5610b13a0a5ff638 -->
# Разберитесь с тем, как подгрузить интерактивную карту города в качестве фона графика. Можно пойти двумя следующими способами.
# 1. Изучить <a href="https://thetahat.ru/courses/python/09" target="_blank">материалы</a> по библиотеке <a href="https://plotly.com/python/" target="_blank"><b>Plotly</b></a>. Возможно, потребуется также заглянуть в документацию.
# 1. Поразбираться с библиотекой <a href="https://github.com/python-visualization/folium" target="_blank"><b>Folium</b></a>. Посмотрите множество <a href="https://nbviewer.org/github/python-visualization/folium/tree/main/examples/" target="_blank">примеров</a>, может также помочь <a href="https://proglib.io/p/python-web-map" target="_blank">статья на русском</a>.
#
# *Внимание!* Интерактивная карта может не сохраниться в ноутбуке, а если сохранится, то вес ноутбука может превзойти 20 Мб, и его не получится отправить боту. В любом случае **<u>необходимо сохранить карту в html и отправить ее отдельным файлом в бот.</u>** При этом каждый файл html должен не превышать 20 Мб, присылать файлы в архиве нельзя. Аналогично со всеми следующими интерактивными графиками в этом задании.

# %%
df_las_vegas = df[df['city'] == 'Las Vegas']
latitude_range = (36.05, 36.2)
longitude_range = (-115.3, -115.0)

df_las_vegas_filtered = df_las_vegas[
    (df_las_vegas['latitude'] >= latitude_range[0]) &
    (df_las_vegas['latitude'] <= latitude_range[1]) &
    (df_las_vegas['longitude'] >= longitude_range[0]) &
    (df_las_vegas['longitude'] <= longitude_range[1])
]

las_vegas_map = folium.Map(location=[36.1699, -115.1398], zoom_start=13, tiles='OpenStreetMap')

marker_cluster = MarkerCluster().add_to(las_vegas_map)

for _, row in df_las_vegas_filtered.iterrows():
    folium.Marker([row['latitude'], row['longitude']], popup=row['name']).add_to(marker_cluster)

las_vegas_map.save("las_vegas_map_clustered.html")

print("Карта сохранена как 'las_vegas_map_clustered.html'")
# Out:
# Карта сохранена как 'las_vegas_map_clustered.html'

# %% [markdown]
# <!-- Внимание! Здесь находится специальная отметка. Ее нельзя удалять! Ответы на вопросы / выводы для предыдущего пункта(ов) пиши в ячейках выше! -->
# <!-- 00000000000000000000000000000000 -->
# Если все получилось, вы молодцы! Далее в этой задаче тоже стройте интерактивные карты. Если нет желания разбираться с интерактивными графиками, можно построить статичные, но баллы будут снижены.

# %% [markdown]
# #### 2. Оценки компаний
#
# Для выполнения задания нужно посчитать среднюю оценку каждой компании, а также количество выставленных оценок.
#
# Загрузите таблицу оценок `yelp_review.csv`.

# %%
df_reviews = pd.read_csv('yelp_review.csv')

print(df_reviews.head())
# Out:
#    Unnamed: 0             business_id  stars
# 0           0  AEx2SYEUJmTxVVB18LlCwA      5
# 1           1  VR6GpWIda3SfvPC-lg9H3w      5
# 2           2  CKC0-MOWMqoeWf6s-szl8g      5
# 3           3  ACFtxLv8pGrrxMm6EgjreA      4
# 4           4  s2I_Ni76bjJNK9yG60iD-Q      4

# %% [markdown]
# В подгруженной таблице оценок оставьте только компании города `N`. Для этого установите значения `business_id` в качестве индекса у таблицы оценок и воспользуйтесь методом `loc`.
#
# *Подсказка.* Чтобы индекс снова сделать полем таблицы, можно воспользоваться методом `reset_index`.

# %%
df_reviews = pd.read_csv('yelp_review.csv')
df_business = pd.read_csv('yelp_business.csv')

city_name = 'Las Vegas'
df_business_city_n = df_business[df_business['city'] == city_name]

df_reviews.set_index('business_id', inplace=True)

df_reviews_filtered = df_reviews.loc[df_reviews.index.isin(df_business_city_n['business_id'])]

df_reviews_filtered.reset_index(inplace=True)

print(df_reviews_filtered)
# Out:
#                     business_id  Unnamed: 0  stars
# 0        8QWPlVQ6D-OExqXoaD2Z1g           5      5
# 1        pLZ9oZM8c6MNbRlg06lBPg          87      1
# 2        6Q7-wkCPc1KF75jZLOTcMw         105      2
# 3        9Jc3W0aR9Xf2gcHI0rEXsw         122      1
# 4        xVEtGucSRLk5pxxN0t4i6g         123      5
# ...                         ...         ...    ...
# 1604222  Q7m8G4579-XYKV3LMW8V7g     5261633      4
# 1604223  3kdSl5mo9dWC4clrQjEDGg     5261634      5
# 1604224  lLMJsTchKYF1O0fpNWpCRA     5261635      5
# 1604225  UicG-oyX4bjmcQbmXn7hGw     5261639      5
# 1604226  HeKfDaa_Fa0fn3-xy9tqDw     5261640      5
#
# [1604227 rows x 3 columns]

# %% [markdown]
# Теперь посчитайте среднюю оценку каждой компании, а также количество выставленных компании оценок.
#
# *Подсказка.* Помочь в этом могут функции `groupby` и `aggregate([np.mean, np.size])`.

# %%
df_reviews_aggregated = df_reviews_filtered.groupby('business_id').agg(
    average_rating=('stars', 'mean'),
    review_count=('stars', 'size')
).reset_index()

print(df_reviews_aggregated)
# Out:
#                   business_id  average_rating  review_count
# 0      --9e1ONYQuAa-CB_Rrw7Tw        4.088904          1451
# 1      --DdmeR16TRb3LsjG0ejrQ        3.200000             5
# 2      --WsruI0IGEoeRmkErU5Gg        4.928571            14
# 3      --Y7NhBKzLTbNliMUX_wfg        4.875000             8
# 4      --e8PjCNhEz32pprnPhCwQ        3.473684            19
# ...                       ...             ...           ...
# 26770  zzOo9n22fBbKAhbSpMzggA        3.230769            26
# 26771  zzXuJF6UUT1kgTyCsmgDmQ        5.000000             4
# 26772  zzjqFOujmM9surbMANZ_ag        5.000000             3
# 26773  zzsKbL1KMNJqazSqBXskxQ        3.666667             6
# 26774  zzzaIBwimxVej4tY6qFOUQ        3.432432            37
#
# [26775 rows x 3 columns]

# %% [markdown]
# Назовите колонки таблицы красивыми именами, изменив `<имя таблицы>.columns`, после чего напечатайте несколько строк полученной таблицы. Красивые имена &mdash; то, что будет понятно простому человеку при чтении ваших результатов. Как именно их назвать &mdash; задача аналитика, то есть в данном случае ваша :)

# %%
df_reviews_aggregated = df_reviews_filtered.groupby('business_id').agg(
    average_rating=('stars', 'mean'),
    review_count=('stars', 'size')
).reset_index()

df_reviews_aggregated.columns = ['Business ID', 'Average Rating', 'Number of Reviews']

print(df_reviews_aggregated.head())
# Out:
#               Business ID  Average Rating  Number of Reviews
# 0  --9e1ONYQuAa-CB_Rrw7Tw        4.088904               1451
# 1  --DdmeR16TRb3LsjG0ejrQ        3.200000                  5
# 2  --WsruI0IGEoeRmkErU5Gg        4.928571                 14
# 3  --Y7NhBKzLTbNliMUX_wfg        4.875000                  8
# 4  --e8PjCNhEz32pprnPhCwQ        3.473684                 19

# %% [markdown]
# Соедините две полученные ранее таблицы по компаниям города `N` в одну.
# Для этого сначала установите поле `business_id` в качестве индекса в обеих таблицах с помощью `set_index`. В одной из них это уже должно было быть сделано.
# В полученной таблице должны получится поля `latitude`, `longitude`, `categories`, `name`, а также две колонки со средней оценкой компаний и количеством оценок, которые вы посчитали выше.
#
# *Подсказка.* Соединение таблиц можно выполнить с помощью `join`.
# Индексы у этих таблиц одинаковые, так что тип джойна не имеет значения.

# %%
df_reviews = pd.read_csv('yelp_review.csv')
df_business = pd.read_csv('yelp_business.csv')

city_name = 'Las Vegas'
df_business_city_n = df_business[df_business['city'] == city_name]

df_business_city_n.set_index('business_id', inplace=True)

df_reviews.set_index('business_id', inplace=True)
df_reviews_filtered = df_reviews.loc[df_reviews.index.isin(df_business_city_n.index)]

df_reviews_aggregated = df_reviews_filtered.groupby('business_id').agg(
    average_rating=('stars', 'mean'),
    number_of_reviews=('stars', 'size')
).reset_index()

df_reviews_aggregated.columns = ['Business ID', 'Average Rating', 'Number of Reviews']

df_reviews_aggregated.set_index('Business ID', inplace=True)

df_combined = df_business_city_n.join(df_reviews_aggregated)

df_combined = df_combined[['latitude', 'longitude', 'categories', 'name', 'Average Rating', 'Number of Reviews']]

print(df_combined.head())
# Out:
#                          latitude   longitude  \
# business_id
# kCoE3jvEtg6UVz5SOD3GVw  36.207430 -115.268460
# OD2hnuuTJI9uotcKycxg1A  36.197484 -115.249660
# VBHEsoXQb2AQ76J9l8h1uQ  36.085051 -115.119421
# 1Jp_hmPNUZArNqzpbm7B0g  36.056382 -115.269332
# DPQnTnNw2PJj7DdENM98Cw  36.105196 -115.056880
#
#                                                                categories  \
# business_id
# kCoE3jvEtg6UVz5SOD3GVw  Real Estate Services;Real Estate;Home Services...
# OD2hnuuTJI9uotcKycxg1A                            Shopping;Sporting Goods
# VBHEsoXQb2AQ76J9l8h1uQ       Shopping;Jewelry;Watch Repair;Local Services
# 1Jp_hmPNUZArNqzpbm7B0g  Home Services;Lighting Fixtures & Equipment;Lo...
# DPQnTnNw2PJj7DdENM98Cw       Nurseries & Gardening;Home & Garden;Shopping
#
#                                        name  Average Rating  Number of Reviews
# business_id
# kCoE3jvEtg6UVz5SOD3GVw         "BDJ Realty"        4.000000                  5
# ...

# %% [markdown]
# <!-- Внимание! Здесь находится специальная отметка. Ее нельзя удалять! Ответы на вопросы / выводы для предыдущего пункта(ов) пиши в ячейках выше! -->
# <!-- bba9ec349279ff7d3caf3717aabafe3e -->
# Изобразите все компании на графике, раскрасив точку в цвет, оттенок которого соответствует средней оценке компании. Прозрачность точки выставляйте не более $0.3$. Если у одной компании несколько филиалов с разными адресами, наносите на график все адреса.

# %%
las_vegas_map = folium.Map(location=[36.1699, -115.1398], zoom_start=13, tiles='OpenStreetMap')

marker_cluster = MarkerCluster().add_to(las_vegas_map)

df_filtered = df_combined[df_combined['Number of Reviews'] >= 5]

df_filtered_high_rating = df_filtered[df_filtered['Average Rating'] >= 4.0]

for _, row in df_filtered_high_rating.iterrows():
    popup_content = f"<b>{row['name']}</b><br>Рейтинг: {row['Average Rating']}, Кол-во отзывов: {row['Number of Reviews']}"

    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=popup_content,
        icon=folium.Icon(color='green' if row['Average Rating'] >= 4.5 else ('orange' if row['Average Rating'] >= 3.5 else 'red'))
    ).add_to(marker_cluster)

las_vegas_map.save("las_vegas_map_with_ratings_optimized.html")

print("Карта сохранена как 'las_vegas_map_with_ratings_optimized.html'")
# Out:
# Карта сохранена как 'las_vegas_map_with_ratings_optimized.html'

# %% [markdown]
# <!-- Внимание! Здесь находится специальная отметка. Ее нельзя удалять! Ответы на вопросы / выводы для предыдущего пункта(ов) пиши в ячейках выше! -->
# <!-- 00000000000000000000000000000000 -->
# Чтобы получить районы города, то есть разделить город на "клетки", округлите значения широты и долготы, подобрав оптимальный размер района.
#
# *Подсказка.* Например, можно сделать так
# `np.round(долгота*4, decimals=1)*0.25`.

# %%
city_name = 'Las Vegas'
df_business_city_n = df_business[df_business['city'] == city_name].copy()

df_business_city_n.loc[:, 'latitude_rounded'] = np.round(df_business_city_n['latitude']*4, decimals=1)*0.25
df_business_city_n.loc[:, 'longitude_rounded'] = np.round(df_business_city_n['longitude']*4, decimals=1)*0.25

print(df_business_city_n[['latitude', 'longitude', 'latitude_rounded', 'longitude_rounded']].head())
# Out:
#      latitude   longitude  latitude_rounded  longitude_rounded
# 6   36.207430 -115.268460            36.200           -115.275
# 7   36.197484 -115.249660            36.200           -115.250
# 26  36.085051 -115.119421            36.075           -115.125
# 41  36.056382 -115.269332            36.050           -115.275
# 48  36.105196 -115.056880            36.100           -115.050

# %% [markdown]
# <!-- Внимание! Здесь находится специальная отметка. Ее нельзя удалять! Ответы на вопросы / выводы для предыдущего пункта(ов) пиши в ячейках выше! -->
# <!-- 228c0524733d5289e94cde00fc9b704b -->
# Для получения средней оценки компаний по району постройте сводную таблицу при помощи `pd.pivot_table`, взяв в качестве индексов и колонок округленные широту и долготу, а в качестве значений &mdash; оценки. Аггрегирующей функцией является среднее.
#
# Изобразите полученную таблицу при помощи `sns.heatmap`.
#
# *Замечание.* В качестве среднего можно было бы посчитать как общее среднее по всем оценкам всех компаний, так и среднее по компаниям их средних оценок. В чем разница этих подходов? Какой из них необходимо использовать в данном случае?

# %%
df_reviews_aggregated = df_reviews_filtered.groupby('business_id').agg(
    average_rating=('stars', 'mean')
).reset_index()

df_combined = df_business_city_n.set_index('business_id').join(df_reviews_aggregated.set_index('business_id'))

pivot_table = pd.pivot_table(df_combined,
                             values='average_rating',
                             index='latitude_rounded',
                             columns='longitude_rounded',
                             aggfunc='mean')

plt.figure(figsize=(14, 12))

sns.heatmap(pivot_table,
            cmap="coolwarm",
            annot=True,
            fmt='.2f',
            annot_kws={'size': 9},
            cbar_kws={'label': 'Средняя оценка'},
            linewidths=0.5,
            linecolor='white')

plt.title('Средняя оценка компаний по районам Лас-Вегаса')
plt.show()

# %% [markdown]
# <!-- Внимание! Здесь находится специальная отметка. Ее нельзя удалять! Ответы на вопросы / выводы для предыдущего пункта(ов) пиши в ячейках выше! -->
# <!-- b4c4e083ebff2a19367f2df3097fcc53 -->
# Полученный график имеет ряд недостатков. Во-первых, не очень правильно судить о районе, если в нем мало компаний. Во-вторых,  на графике цветовая гамма автоматически подстроилась под минимальное и максимальное значения оценки.
#
# Почему эти недостатки могут быть существенными?
#
# **Ответ:**
# 1. Мало компаний в районе:
#
#     Если в районе мало компаний, средняя оценка может быть искажена случайными аномальными оценками, что делает выводы ненадежными.
#
# 2. Цветовая гамма автоматически подстраивается:
#
#     Цветовая гамма, подстраивающаяся под минимальные и максимальные значения, может выделить экстремальные оценки, искажающие восприятие более сбалансированных районов.
#
# Рекомендации:
#
# - Установить минимальный порог для числа компаний в районе.
# - Использовать фиксированные пределы для цветовой гаммы.
# - Рассматривать взвешенные оценки для более точной картины.

# %% [markdown]
# <!-- Внимание! Здесь находится специальная отметка. Ее нельзя удалять! Ответы на вопросы / выводы для предыдущего пункта(ов) пиши в ячейках выше! -->
# <!-- e8acf0d523beb5602fbacb4f19b6e912 -->
# Оставьте районы, в которых имеется информация о не менее $30$ компаний. Постройте новый график районов, использовав параметры `vmin` и `vmax` у функции `sns.heatmap`.

# %%
df_filtered = df_combined.groupby(['latitude_rounded', 'longitude_rounded']).size()
df_filtered = df_filtered[df_filtered >= 30]

df_combined_filtered = df_combined[
    df_combined.set_index(['latitude_rounded', 'longitude_rounded']).index.isin(df_filtered.index)
]

pivot_table_filtered = pd.pivot_table(df_combined_filtered,
                                      values='average_rating',
                                      index='latitude_rounded',
                                      columns='longitude_rounded',
                                      aggfunc='mean')

plt.figure(figsize=(10, 8))
sns.heatmap(pivot_table_filtered, cmap="YlGnBu", annot=True, fmt='.2f',
            cbar_kws={'label': 'Средняя оценка'},
            vmin=1, vmax=5, linewidths=0.5)
plt.title('Средняя оценка компаний по районам Лас-Вегаса (не менее 30 компаний)')
plt.show()

# %% [markdown]
# Сравните полученный график с предыдущим и сделайте вывод.
#
# **Вывод:**
# - На графике остались только районы с более стабильной и надежной статистикой, поскольку в них больше компаний, и их средние оценки менее подвержены искажениям.
# - Использование фиксированных значений vmin и vmax для цветовой гаммы позволило улучшить восприятие, обеспечив одинаковые масштабы для всех районов, что делает сравнение более объективным.
# - График стал более точным и предсказуемым, так как данные о районах с недостаточным количеством компаний были исключены.
#
# Фильтрация районов по количеству компаний улучшила качество анализа. Теперь на графике представлены только те районы, где достаточно данных для надежных выводов. Фиксированные параметры цветовой гаммы позволяют более честно визуализировать различия между районами.

# %% [markdown]
# <!-- Внимание! Здесь находится специальная отметка. Ее нельзя удалять! Ответы на вопросы / выводы для предыдущего пункта(ов) пиши в ячейках выше! -->
# <!-- 41f197dab9cc006425d5cbab8bcc12f8 -->
# #### 3. Рестораны
#
# Будем считать компанию рестораном, если в поле `categories` *содержится* слово `restaurant`. Обратите внимание, что в анализе данных часто нет четкого формата данных. Например, данное слово может быть написано как с большой буквы, так и с маленькой; может как разделяться `;`, так и не разделяться. При возникновении недопонимания стоит посмотреть данные.
#
# Составьте таблицу, в которой будет информация о всех ресторанах города `N`, для которых имеется не менее $5$ отзывов. Далее постройте heatmap-график районов, в котором каждому району сопоставьте среднюю оценку по ресторанам этого района. Рассматривайте только те районы, в которых есть не менее $10$ ресторанов, для каждого из которых есть не менее $5$ отзывов.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df_reviews = pd.read_csv('yelp_review.csv')
df_business = pd.read_csv('yelp_business.csv')

city_name = 'Las Vegas'
df_business_city = df_business[df_business['city'] == city_name].copy()

df_restaurants = df_business_city[df_business_city['categories'].str.contains('restaurant', case=False, na=False)].copy()

df_reviews_filtered = df_reviews[df_reviews['business_id'].isin(df_restaurants['business_id'])].copy()
df_review_counts = df_reviews_filtered.groupby('business_id').size()
valid_restaurants = df_review_counts[df_review_counts >= 5].index

df_valid_restaurants = df_restaurants[df_restaurants['business_id'].isin(valid_restaurants)].copy()

df_valid_restaurants.loc[:, 'latitude_rounded'] = np.round(df_valid_restaurants['latitude'] * 4, decimals=1) * 0.25
df_valid_restaurants.loc[:, 'longitude_rounded'] = np.round(df_valid_restaurants['longitude'] * 4, decimals=1) * 0.25

df_reviews_avg = df_reviews_filtered.groupby('business_id')['stars'].mean()
df_valid_restaurants.loc[:, 'average_rating'] = df_valid_restaurants['business_id'].map(df_reviews_avg)

df_district_counts = df_valid_restaurants.groupby(['latitude_rounded', 'longitude_rounded']).size()
valid_districts = df_district_counts[df_district_counts >= 10].index
df_final = df_valid_restaurants[df_valid_restaurants.set_index(['latitude_rounded', 'longitude_rounded']).index.isin(valid_districts)].copy()

pivot_table = pd.pivot_table(df_final, values='average_rating', index='latitude_rounded', columns='longitude_rounded', aggfunc='mean')

plt.figure(figsize=(10, 8))
sns.heatmap(pivot_table, cmap="coolwarm", annot=True, fmt='.2f', cbar_kws={'label': 'Средняя оценка'}, vmin=1, vmax=5, linewidths=0.5)
plt.title('Средняя оценка ресторанов по районам Лас-Вегаса')
plt.show()

# %% [markdown]
# Чем полезны ограничения снизу на количество отзывов для ресторана и количество ресторанов в районе?
#
# **Ответ:**
# Ограничения снизу на количество отзывов и ресторанов помогают улучшить качество анализа:
#
# - Фильтрация шумовых данных – Рестораны с 1–2 отзывами могут иметь нерепрезентативные оценки, поскольку они зависят от субъективного мнения нескольких клиентов. Ограничение от 5 отзывов помогает учитывать только более объективные рейтинги.
# - Повышение статистической значимости – Если в районе всего 1–2 ресторана, их средняя оценка может быть случайной. Ограничение от 10 ресторанов уменьшает влияние отдельных заведений и делает среднюю оценку более надежной.
#
# - Более точная картина районов – Исключая малонаселенные ресторанами районы, мы получаем карту, где показатели действительно отражают уровень сервиса, а не случайные выбросы.
#
# Таким образом, такие ограничения помогают избежать искажений и делают результаты анализа более точными

# %% [markdown]
# <!-- Внимание! Здесь находится специальная отметка. Ее нельзя удалять! Ответы на вопросы / выводы для предыдущего пункта(ов) пиши в ячейках выше! -->
# <!-- cae6db258b07ada817b6c441921e0cd8 -->
# Кот Василий из города `N` очень придирчив к выбору ресторана. Он доверяет только ресторанам с высоким рейтингом, который основывается на большом количестве отзывов. Напечатайте в виде таблицы информацию $10$ ресторанах с самым большим рейтингом в порядке убывания рейтинга. Для каждого из этих ресторанов должно быть не менее $50$ отзывов. По каждому ресторану необходимо вывести следующую информации: название ресторана, средняя оценка, количество отзывов, географические координаты, категории.

# %%
df_reviews_counts = df_reviews_filtered.groupby('business_id').size().reset_index(name='number_of_reviews')
df_valid_restaurants = df_restaurants.merge(df_reviews_counts, on='business_id')
df_valid_restaurants = df_valid_restaurants[df_valid_restaurants['number_of_reviews'] >= 50]

df_reviews_avg = df_reviews_filtered.groupby('business_id')['stars'].mean().reset_index(name='average_rating')
df_valid_restaurants = df_valid_restaurants.merge(df_reviews_avg, on='business_id')

df_top_restaurants = df_valid_restaurants.sort_values(by='average_rating', ascending=False).head(10)

df_top_restaurants = df_top_restaurants[['name', 'average_rating', 'number_of_reviews', 'latitude', 'longitude', 'categories']]
print(df_top_restaurants)
# Out:
#                                name  average_rating  number_of_reviews  \
# 372     "Lip Smacking Foodie Tours"        4.966480                179
# 2693                 "Pepito Shack"        4.907692                 65
# 1740               "Bosa Boba Cafe"        4.890909                 55
# 2728                 "Garden Grill"        4.868132                 91
# 201                  "Brew Tea Bar"        4.848069               1165
# 2000               "Poppa Naps BBQ"        4.836538                104
# 1267               "Zenaida's Cafe"        4.833333                180
# 1250   "El Frescos Cocina Mexicana"        4.816754                191
# 538   "Blaqcat Ultra Hookah Lounge"        4.809524                 63
# 2497     "California Sushi Burrito"        4.807018                 57
#
#        latitude   longitude                                         categories
# 372   36.114537 -115.172678  Food Tours;Restaurants;Event Planning & Servic...
# ...

# %% [markdown]
# <!-- Внимание! Здесь находится специальная отметка. Ее нельзя удалять! Ответы на вопросы / выводы для предыдущего пункта(ов) пиши в ячейках выше! -->
# <!-- 3dfd6f8a8d445e64850dc7cb2d5beca9 -->
# Нанесите на карту все рестораны со средней оценкой не менее $4.7$, которая посчитана по не менее $50$ отзывам. Отдельным цветом отметьте 10 ресторанов, которые вы получили ранее.

# %%
import folium
from folium.plugins import MarkerCluster

df_best_restaurants = df_valid_restaurants[
    (df_valid_restaurants['average_rating'] >= 4.7) & (df_valid_restaurants['number_of_reviews'] >= 50)
]

las_vegas_map = folium.Map(location=[36.1699, -115.1398], zoom_start=13, tiles='OpenStreetMap')

marker_cluster = MarkerCluster().add_to(las_vegas_map)

for _, row in df_best_restaurants.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=f"{row['name']}<br>Категории: {row['categories']}<br>Средняя оценка: {row['average_rating']}<br>Количество отзывов: {row['number_of_reviews']}",
        icon=folium.Icon(color='blue')  # Голубой цвет для всех ресторанов 4.7+
    ).add_to(marker_cluster)

for _, row in df_top_restaurants.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=f"ТОП-10! {row['name']}<br>Категории: {row['categories']}<br>Средняя оценка: {row['average_rating']}<br>Количество отзывов: {row['number_of_reviews']}",
        icon=folium.Icon(color='red')  # Красный цвет для ТОП-10
    ).add_to(las_vegas_map)

las_vegas_map.save("las_vegas_best_restaurants_map.html")
print("Карта сохранена как 'las_vegas_best_restaurants_map.html'")
# Out:
# Карта сохранена как 'las_vegas_best_restaurants_map.html'

# %% [markdown]
# <!-- Внимание! Здесь находится специальная отметка. Ее нельзя удалять! Ответы на вопросы / выводы для предыдущего пункта(ов) пиши в ячейках выше! -->
# <!-- 7ddef107ae40b08ee84032d80dbfe73c -->
# Охарактеризуйте кота Василия, а также сделайте общий вывод по задаче.
#
# **Вывод:**
# Кот Василий – невероятно разборчивый и требовательный к выбору ресторана. Он доверяет только проверенным заведениям, которые получили высокий средний рейтинг и основаны на большом количестве отзывов. Для него важно, чтобы мнение было объективным, а не результатом случайных оценок.
#
# 1. Фильтрация и анализ данных
#
#     Были выбраны рестораны с достаточным количеством отзывов (не менее 5)
#     Для карты топовых мест были установлены жесткие ограничения (рейтинг ≥ 4.7, отзывы ≥ 50)
#
# 2. Визуализация через интерактивную карту
#
#     Использовались кластерные маркеры для уменьшения размера карты
#     Рестораны с высоким рейтингом были отмечены голубым цветом, а ТОП-10 – красным
#     Всплывающие окна содержали название, категории, рейтинг и количество отзывов
#
# 3. Оптимизация размера карты
#
#     Уменьшено число загруженных точек
#     Использованы кластерные маркеры для снижения нагрузки
#     Карта весила менее 20 МБ, что делает её удобной для просмотра
#
# Итог: Мы автоматизировали анализ ресторанов, построили наглядную карту, сохранили её в HTML и нашли лучшие заведения для кота Василия. Теперь он всегда сможет найти идеальное место для обеда, а мы – получить полезную информацию о ресторанах в городе.

# %% [markdown]
# <!-- Внимание! Здесь находится специальная отметка. Ее нельзя удалять! Ответы на вопросы / выводы для предыдущего пункта(ов) пиши в ячейках выше! -->
# <!-- 50003c7e0087be3d9377b547465ce334 -->
# ---
#
# ### Задача 4.
#
# **При использовании ИИ в этой задаче необходимо прислать файл `task_4_ai_promt.txt` с копией вашего диалога с ИИ-инструментом**
#
# Представьте ситуацию, вы занимаетесь своей научной работой, и вам попалась одна интересная статья. Прежде чем глубоко погружаться в решение авторов вам хотелось бы понять, какую задачу решают авторы, насколько успешно, какие у них данные, какие навыки нужны для понимания. Например, было бы очень не оптимально последовательно глубоко разбирать все статьи, на это нужно потратить очень много времени. Предварительный анализ позволяет понять, какие решения в статьях существуют, выделить для себя наиболее интересные. Благодаря изобретению ИИ вы можете ускорить анализ статьей, быстрее разбираться в научных статьях, которые вам действительно интересны.
#
# **Выполните следующие действия**
#
# * Выберите одну научную статью из списка ниже.
#
# * Опишите **постановку задачи:** 1). на простом языке, чтобы ее могли понять люди без технического образования, 2). на математическом языке. Возможно, некоторые моменты окажутся сложными, тем не менее, попробуйте выделить ключевые элементы, используя ИИ.
#
# * Разберите **структуру входных данных**, которые использует решение авторов. Опишите их тип, например, таблица признаков, изображения с метками, текстовые данные с категориями, а также формат представления. Например, случае метода KNN это матрица признаков размером $n \times d$ и вектор меток размером $n$.
#
# * Определите **ограничения на данные**. Уточните, есть ли требования к их балансу, наличию пропущенных значений, допустимым диапазонам чисел и другим характеристикам.
#
# * Выясните, **решает ли предложенная модель поставленную задачу** по мнению авторов. Обратите внимание на используемые метрики и проанализируйте, насколько они подтверждают успешность решения. Погружаться в работу метрик не требуется, достаточно лишь кратко изложить основные результаты.
#
# * Опишите, **какими знаниями необходимо обладать** для понимания работы модели. Это могут быть основы математики, такие как линейная алгебра и теория вероятностей, а также навыки программирования, например, владение Python и библиотеками машинного обучения.
#
# *Примечание.*
# * Ожидаемый объем работы: 200-300 слов.
# * Расчетное время выполнения: 1 час.

# %% [markdown]
# #### **Трансформеры и языковые модели**
# 1. **Attention is All You Need**
#    *Vaswani et al., NeurIPS 2017*
#    [arXiv:1706.03762](https://arxiv.org/abs/1706.03762)
#
# 2. **BERT: Pre-training of Deep Bidirectional Transformers for Language Understanding**
#    *Devlin et al., NAACL 2019*
#    [arXiv:1810.04805](https://arxiv.org/abs/1810.04805)
#
# 3. **Language Models are Few-Shot Learners**
#    *Brown et al., NeurIPS 2020*
#    [arXiv:2005.14165](https://arxiv.org/abs/2005.14165)
#
# 4. **Exploring the Limits of Transfer Learning with a Unified Text-to-Text Transformer**
#    *Raffel et al., JMLR 2020*
#    [arXiv:1910.10683](https://arxiv.org/abs/1910.10683)
#
# 5. **Scaling Laws for Neural Language Models**
#    *Kaplan et al., NeurIPS 2020*
#    [arXiv:2001.08361](https://arxiv.org/abs/2001.08361)
#
# 6. **Llama 2: Open Foundation and Fine-Tuned Chat Models**
#    *Meta AI, 2023*
#    [arXiv:2307.09288](https://arxiv.org/abs/2307.09288)
#
# 7. **GPT-4 Technical Report**
#    *OpenAI, 2023*
#    [arXiv:2303.08774](https://arxiv.org/abs/2303.08774)
#
# 8. **Gemini: A Family of Highly Capable Multimodal Models**
#    *Google DeepMind, 2023*
#    [arXiv:2312.11805](https://arxiv.org/abs/2312.11805)
#
#
# #### **Компьютерное зрение и визуальные модели**
# 9. **An Image is Worth 16x16 Words: Transformers for Image Recognition at Scale**
#    *Dosovitskiy et al., ICLR 2021*
#    [arXiv:2010.11929](https://arxiv.org/abs/2010.11929)
#
# 10. **Learning Transferable Visual Models From Natural Language Supervision**
#     *Radford et al., ICML 2021*
#     [arXiv:2103.00020](https://arxiv.org/abs/2103.00020)
#
# 11. **Segment Anything**
#     *Kirillov et al., Meta AI, 2023*
#     [arXiv:2304.02643](https://arxiv.org/abs/2304.02643)
#
# 12. **Scaling Vision Transformers to 22 Billion Parameters**
#     *Dehghani et al., Google DeepMind, 2023*
#     [arXiv:2302.05442](https://arxiv.org/abs/2302.05442)
#
# #### **Self-Supervised and Contrastive Learning**
# 13. **A Simple Framework for Contrastive Learning of Visual Representations**
#     *Chen et al., CVPR 2020*
#     [arXiv:2002.05709](https://arxiv.org/abs/2002.05709)
#
# 14. **Self-Supervised Learning of Pretext-Invariant Representations**
#     *Misra and Maaten, CVPR 2020*
#     [arXiv:1912.01991](https://arxiv.org/abs/1912.01991)
#
# 15. **Big Self-Supervised Models are Strong Semi-Supervised Learners**
#     *Chen et al., NeurIPS 2020*
#     [arXiv:2006.10029](https://arxiv.org/abs/2006.10029)
#
# 16. **Unsupervised Learning of Visual Features by Contrasting Cluster Assignments**
#     *Caron et al., NeurIPS 2020*
#     [arXiv:2006.09882](https://arxiv.org/abs/2006.09882)
#
# #### **Обучение с подкреплением**
# 17. **Reinforcement Learning with Augmented Data**
#    *Laskin et al., NeurIPS 2020*
#    [arXiv:2004.14990](https://arxiv.org/abs/2004.14990)
#
# 18. **Neural Architecture Search with Reinforcement Learning**
#    *Zoph and Le, ICLR 2017*
#    [arXiv:1611.01578](https://arxiv.org/abs/1611.01578)
#
#
# #### **Архитектуры нейросетей и их масштабирование**
# 19. **EfficientNet: Rethinking Model Scaling for Convolutional Neural Networks**
#    *Tan and Le, ICML 2019*
#    [arXiv:1905.11946](https://arxiv.org/abs/1905.11946)
#
# 20. **Emergent Abilities of Large Language Models**
#    *Wei et al., 2023*
#    [arXiv:2206.07682](https://arxiv.org/abs/2206.07682)
#
# 21. **Scaling Data-Constrained Language Models**
#    *Muennighoff et al., 2023*
#    [arXiv:2305.16264](https://arxiv.org/abs/2305.16264)
#
#
# #### **Математика, байесовские методы и причинно-следственный анализ**
# 22. **Deep Learning for Symbolic Mathematics**
#     *Lample and Charton, ICLR 2020*
#     [arXiv:1912.01412](https://arxiv.org/abs/1912.01412)
#
# 23. **Causal Inference with a Functional Outcome**
#     *Ecker et al., 2023*
#     [arXiv:2304.07113](https://arxiv.org/abs/2304.07113)
#
# 24. **General Bayesian Inference for Causal Effects Using Covariate Balancing Procedure**
#     *Orihara et al., 2024*
#     [arXiv:2404.09414](https://arxiv.org/abs/2404.09414)
#
# 25. **A Deep-Learning Based Bayesian Approach to Seismic Imaging and Uncertainty Quantification**
#     *Siahkoohi et al., 2020*
#     [arXiv:2001.04567](https://arxiv.org/abs/2001.04567)
#
# 26. **Robust Inference for High-Dimensional Linear Models**
#     *Wang et al., 2021*
#     [arXiv:2106.07717](https://arxiv.org/abs/2106.07717)

# %% [markdown]
# **Выбранная статья:** Deep Learning for Symbolic Mathematics
# Lample and Charton, ICLR 2020

# %% [markdown]
# **Анализ статьи:**

# %% [markdown]
# # Описание статьи "Deep Learning for Symbolic Mathematics"
#
# ### **1. Предшествующие работы и их вклад**
#
# #### **Классические системы символьной математики**
#
# - **Risch (1970)**: предложил алгоритм для аналитического интегрирования, который до сих пор не полностью реализован в компьютерных алгебраических системах (CAS) вроде Mathematica, Maple и Matlab.
# - **Geddes et al. (1992)**: разработали методы обработки сложных математических выражений в компьютерной алгебре.
#
#   🔹 **Связь с текущей работой**: авторы статьи стремятся заменить традиционные алгоритмы на нейросетевые методы, которые обучаются на примерах, а не следуют строгим правилам.
#
# #### **Нейросети для математических задач**
#
# - **Zaremba et al. (2014)**: применили рекурсивные нейросети для упрощения алгебраических выражений.
# - **Loos et al. (2017)**: исследовали использование глубокого обучения для автоматического поиска математических доказательств.
# - **Arabshahi et al. (2018)**: использовали нейросети для предсказания пропущенных элементов в математических уравнениях.
#
#   🔹 **Связь с текущей работой**: все эти исследования фокусируются на представлении математических выражений с помощью нейросетевых моделей.
#
# ---
#
# ### **2. Постановка задачи**
# Традиционно символьные математические вычисления выполняются с использованием алгоритмов, основанных на чётких правилах (например, алгоритм Риша для интегрирования). Однако такие методы зачастую оказываются сложными и не всегда универсальными. В этой работе авторы рассматривают возможность применения нейросетевых моделей seq2seq (sequence-to-sequence) для решения задач **символьного интегрирования** и **решения обыкновенных дифференциальных уравнений (ODEs)**. Основная идея заключается в замене традиционных алгоритмов машинным обучением, при котором модель обучается находить решения на основе большого количества примеров.
#
# ---
#
# ### **3. Структура входных данных**
# Входные данные представлены в виде **деревьев математических выражений**, которые затем преобразуются в последовательности токенов (префиксная запись, обратная польская нотация). Датасеты генерируются тремя методами:
# - **FWD (Forward generation)** – случайные функции и их интегралы, вычисленные CAS-системами.
# - **BWD (Backward generation)** – случайные функции и их производные (интегрирование заменяется дифференцированием).
# - **IBP (Integration by parts)** – интегралы, полученные методом интегрирования по частям.
#
# Для ODEs используются уравнения первого и второго порядка, решения которых могут быть выражены аналитически.
#
# ---
#
# ### **4. Ограничения на данные**
# - **Максимальная длина выражений** – 512 токенов.
# - **Числовые значения** – числа от -5 до 5 (исключая 0).
# - **Используемые операторы**:
#   - 4 бинарных ("+", "-", "×", "/")
#   - 15 унарных ("exp", "log", "sin", "cos" и др.)
# - **Фильтрация данных** – исключены невалидные выражения (например, \( \log(0) \) или \( \sqrt{-2} \)).
# - **Дисбаланс в данных** – FWD генерирует короткие входные выражения и длинные решения, BWD – наоборот.
#
# ---
#
# ### **5. Экспериментальная часть**
#
# **Объем данных:**
# - **Интегрирование**: 80 млн примеров (FWD, BWD, IBP).
# - **ODEs**: 80 млн примеров (уравнения 1-го и 2-го порядка).
#
# **Разбиение данных:**
# - **Обучающая выборка**: 95%
# - **Тестовая выборка**: 5000 примеров
#
# **Архитектура модели:**
# - 6 слоев, 512 скрытых нейронов
# - 8 attention heads
# - Adam (lr=0.0001)
# - Beam search (размер: 1, 10, 50)
#
# **Оценка:**
# - Для проверки корректности решений использовалась библиотека SymPy.
# - Лучшие результаты были получены при beam=50.
#
# ---
#
# ### **6. Решает ли предложенная модель поставленную задачу?**
# Авторы демонстрируют, что их модель **превосходит CAS-системы** (Mathematica, Maple, Matlab) по точности на тестовых данных:
# - **Интегрирование (BWD)**: 99.7% (beam=50)
# - **ODE (1-й порядок)**: 97.0% (beam=50)
# - **ODE (2-й порядок)**: 81.0% (beam=50)
#
# Эти результаты подтверждают, что нейросетевые методы способны **заменить классические алгоритмы** в задачах символьного интегрирования.
#
# ---
#
# ### **7. Необходимые знания для понимания работы модели**
#
# 1. **Математика**
#    - Линейная алгебра (матрицы, собственные значения)
#    - Теория вероятностей (функции потерь, оптимизация)
#    - Символьные вычисления (интегралы, дифференциальные уравнения)
#
# 2. **Программирование**
#    - Python (PyTorch/TensorFlow, SymPy)
#    - Seq2Seq и трансформеры (Attention is All You Need, Vaswani et al.)
#
# 3. **Обработка данных**
#    - Префиксная запись выражений
#    - Глубокое обучение для последовательностей
#
# ---
#
#
# ### **8. Применение на практике**
# 1️⃣ **Компьютерная алгебра** – улучшение систем Mathematica, Maple, Matlab.
# 2️⃣ **Образование** – автоматизация проверки решений, создание учебных примеров.
# 3️⃣ **Научные исследования** – помощь в физике, биоинформатике, инженерии.
# 4️⃣ **Искусственный интеллект** – автоматическое программирование математических вычислений.
#
# Модель открывает **новые возможности в автоматизированных математических вычислениях**, заменяя сложные алгоритмы на нейросетевые методы. 🚀
#
# ---
#
# ### **9. Выводы**
# ✅ **Модель успешно решает задачи символьной математики** и превосходит CAS-системы.
# ✅ **Seq2Seq-архитектура с трансформерами** показала высокую точность, особенно в интегрировании.
# ⚠ **Сложные дифференциальные уравнения (2-й порядок) решаются хуже (81.0%)**, что требует дальнейшего улучшения модели.
# ⚠ **Генерация данных может не покрывать все возможные типы выражений**, что снижает обобщаемость.
#
# ---
# # Анализ сильных и слабых сторон статьи
#
# ## 🔹 Сильные стороны:
#
# - ✅ **Высокая точность** – модель достигает 99.7% при решении задач на интегрирование, превосходя традиционные системы (Mathematica, Maple, Matlab).
# - ✅ **Инновационный подход** – впервые применяется комбинация seq2seq и трансформеров для решения задач символьной математики.
# - ✅ **Гибкость метода** – использование различных методов генерации данных (FWD, BWD, IBP) позволяет работать с разнообразными выражениями.
# - ✅ **Автоматизация вычислений** – модель обучается на примерах, а не следует фиксированным правилам, что повышает её адаптивность.
#
# ## ⚠ Возможные недостатки и ограничения:
#
# - ❌ **Ограниченность генерации данных** – методы FWD и BWD могут не охватывать все возможные типы выражений, что влияет на способность модели обобщать.
# - ❌ **Чувствительность к длине выражений** – точность снижается для длинных уравнений (>512 токенов).
# - ❌ **Неясность о реальной сложности решений** – модель может находить эквивалентные выражения, но насколько они удобны для человека – не анализируется.
# - ❌ **Отсутствие проверки на обобщаемость** – модель обучалась на синтетически сгенерированных данных, но её способность работать с реальными задачами остаётся под вопросом.
# - ❌ **Зависимость от beam search** – для сложных задач точность значительно падает без большого числа гипотез (например, ODE 2-го порядка: 40.8% при beam=1, 81.0% при beam=50).
#
# ---
